# %%
#IMPORT THE LIBRARIES
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
import IPython.display as ipd
from IPython.display import Audio
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD



import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import tensorflow as tf 
print ("Done")
# Out:
# WARNING:tensorflow:From C:\Users\Prade\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Done

# %%
#preparing data set

ravdess = "R_dataset"
ravdess_directory_list = os.listdir(ravdess)
print(ravdess_directory_list)
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_16', 'Actor_17', 'Actor_18', 'Actor_19', 'Actor_20', 'Actor_21', 'Actor_22', 'Actor_23', 'Actor_24']

# %%
# Dictionary mapping numerical labels to emotions
emotion_mapping = {
    1: 'neutral',
    2: 'calm',
    3: 'happy',
    4: 'sad',
    5: 'angry',
    6: 'fearful',
    7: 'disgust',
    8: 'surprised'
}

file_emotion = []
file_path = []
for i in ravdess_directory_list:
    # as their are 24 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(ravdess+'/'+i)
    for f in actor:
        part = f.split('.')[0].split('-')
    # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(ravdess +'/'+ i + '/' + f)

# %%
print(actor[0])
print(part[0])
print(file_path[0])
print(int(part[2]))
print(f)
# Out:
# 03-01-01-01-01-01-24.wav
# 03
# R_dataset/Actor_01/03-01-01-01-01-01-01.wav
# 8
# 03-01-08-02-02-02-24.wav

# %%
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
ravdess_df = pd.concat([emotion_df, path_df], axis=1)
# changing integers to actual emotions.
ravdess_df.Emotions.replace({1:'neutral', 2:'neutral', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust',
                             8:'surprise'},
                            inplace=True)
print(ravdess_df.head())
print("______________________________________________")
print(ravdess_df.tail())
print("_______________________________________________")
print(ravdess_df.Emotions.value_counts())
# Out:
#   Emotions                                         Path
# 0  neutral  R_dataset/Actor_01/03-01-01-01-01-01-01.wav
# 1  neutral  R_dataset/Actor_01/03-01-01-01-01-02-01.wav
# 2  neutral  R_dataset/Actor_01/03-01-01-01-02-01-01.wav
# 3  neutral  R_dataset/Actor_01/03-01-01-01-02-02-01.wav
# 4  neutral  R_dataset/Actor_01/03-01-02-01-01-01-01.wav
# ______________________________________________
#       Emotions                                         Path
# 1435  surprise  R_dataset/Actor_24/03-01-08-01-02-02-24.wav
# 1436  surprise  R_dataset/Actor_24/03-01-08-02-01-01-24.wav
# 1437  surprise  R_dataset/Actor_24/03-01-08-02-01-02-24.wav
# 1438  surprise  R_dataset/Actor_24/03-01-08-02-02-01-24.wav
# 1439  surprise  R_dataset/Actor_24/03-01-08-02-02-02-24.wav
# _______________________________________________
# Emotions
# neutral     288
# happy       192
# sad         192
# angry       192
# fear        192
# disgust     192
# surprise    192
# Name: count, dtype: int64

# %%
#creating Dataframe using all the 4 dataframes we created so far.
data_path = pd.concat([ravdess_df], axis = 0)
data_path.to_csv("data_path.csv",index=False)
data_path.head()
# Out:
#   Emotions                                         Path
# 0  neutral  R_dataset/Actor_01/03-01-01-01-01-01-01.wav
# 1  neutral  R_dataset/Actor_01/03-01-01-01-01-02-01.wav
# 2  neutral  R_dataset/Actor_01/03-01-01-01-02-01-01.wav
# 3  neutral  R_dataset/Actor_01/03-01-01-01-02-02-01.wav
# 4  neutral  R_dataset/Actor_01/03-01-02-01-01-01-01.wav

# %%
print(data_path.Emotions.value_counts())
# Out:
# Emotions
# neutral     288
# happy       192
# sad         192
# angry       192
# fear        192
# disgust     192
# surprise    192
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.title('Count of Emotions', size=16)
sns.countplot(x=data_path.Emotions)
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
plt.show()

# %%
data, sr = librosa.load(path_df.iloc[0, 0])
sr
# Out:
# 22050

# %%
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# CREATE LOG MEL SPECTROGRAM
plt.figure(figsize=(10, 3))
plt.savefig("Spectogram")
spectrogram = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=128,fmax=8000) 
log_spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(log_spectrogram, y_axis='mel', sr=sr, x_axis='time');
plt.title('Mel Spectrogram ')
plt.colorbar(format='%+2.0f dB')

# %%
mfcc = librosa.feature.mfcc(y=data, sr=sr, n_mfcc=30)


# MFCC
plt.figure(figsize=(16, 10))
plt.savefig("MFCC")

plt.subplot(3,1,1)
librosa.display.specshow(mfcc, x_axis='time')
plt.ylabel('MFCC')
plt.colorbar()

ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# NOISE
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

# STRETCH
def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)
# SHIFT
def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)
# PITCH
def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(y=data, sr=sampling_rate, n_steps=pitch_factor)

# %%
# NORMAL AUDIO


import librosa.display
plt.savefig("NormalAudio")

plt.figure(figsize=(12, 3))
librosa.display.waveshow(y=data, sr=sr)
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# AUDIO WITH NOISE
x = noise(data)
plt.figure(figsize=(12,3))
plt.savefig("NoicedAudio")

librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# SHIFTED AUDIO
x = shift(data)
plt.figure(figsize=(12,3))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# SHIFTED AUDIO
x = shift(data)
plt.figure(figsize=(12,4))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def zcr(data, frame_length, hop_length):
    zcr = librosa.feature.zero_crossing_rate(data, frame_length=frame_length, hop_length=hop_length)
    return np.squeeze(zcr)

def chroma(data, sr, frame_length=2048, hop_length=512, flatten=True):
    chroma_result = librosa.feature.chroma_stft(y=data, sr=sr, n_fft=frame_length, hop_length=hop_length)
    return np.squeeze(chroma_result.T) if not flatten else np.ravel(chroma_result.T)

def mfcc(data, sr, frame_length=2048, hop_length=512, flatten=True):
    mfcc_result = librosa.feature.mfcc(y=data, sr=sr, n_fft=frame_length, hop_length=hop_length)
    return np.squeeze(mfcc_result.T) if not flatten else np.ravel(mfcc_result.T)

def extract_features(data, sr=22050, frame_length=2048, hop_length=512):
    result = np.array([])
    
    result = np.hstack((result,
                        zcr(data, frame_length, hop_length),
                        chroma(data, sr, frame_length, hop_length),
                        mfcc(data, sr, frame_length, hop_length)
                       ))
    return result

def get_features(path, duration=2.5, offset=0.6):
    data, sr = librosa.load(path, duration=duration, offset=offset)
    aud = extract_features(data)
    audio = np.array(aud)
    
    # Assuming you have defined functions for noise and pitch
    noised_audio = noise(data)
    aud2 = extract_features(noised_audio)
    audio = np.vstack((audio, aud2))
    
    pitched_audio = pitch(data, sr)
    aud3 = extract_features(pitched_audio)
    audio = np.vstack((audio, aud3))
    
    pitched_audio1 = pitch(data, sr)
    pitched_noised_audio = noise(pitched_audio1)
    aud4 = extract_features(pitched_noised_audio)
    audio = np.vstack((audio, aud4))
    
    return audio

# %%
import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())
# Out:
# Number of processors:  12

# %%
import timeit
from tqdm import tqdm

start = timeit.default_timer()
X, Y = [], []

# Iterate over each audio file path, emotion, and index
for path, emotion, index in tqdm(zip(data_path.Path, data_path.Emotions, range(data_path.Path.shape[0]))):
    # Extract features for the current audio file
    features = get_features(path)
    
    # Print progress every 500 iterations
    if index % 500 == 0:
        print(f'{index} audio files have been processed')
    
    # Append features and emotion labels to X and Y lists
    for i in features:
        X.append(i)
        Y.append(emotion)

print('Done')
stop = timeit.default_timer()

print('Time:', stop - start)
# Out:
# 1it [00:00,  1.67it/s]
# 0 audio files have been processed
# 501it [05:31,  1.49it/s]
# 500 audio files have been processed
# 1001it [11:15,  1.32it/s]
# 1000 audio files have been processed
# 1440it [16:28,  1.46it/s]
# Done
# Time: 988.8726591999875

# %%
    len(X), len(Y), data_path.Path.shape
# Out:
# (5760, 5760, (1440,))

# %%
Emotions = pd.DataFrame(X)
Emotions['Emotions'] = Y
Emotions.to_csv('emotion1.csv', index=False)
Emotions.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.173828  0.264648  0.372559  0.486328  0.625488  0.681152  0.720703
# 1  0.250977  0.389160  0.511719  0.505859  0.510742  0.493164  0.490723
# 2  0.256348  0.354492  0.471191  0.414062  0.378418  0.373535  0.354492
# 3  0.223633  0.343750  0.476562  0.486328  0.504883  0.503418  0.489746
# 4  0.247070  0.389648  0.564941  0.642578  0.665527  0.684570  0.676270
#
#           7         8         9  ...      3555      3556      3557      3558  \
# 0  0.651855  0.562988  0.559082  ...  0.766315  0.755441  0.743671  0.731043
# 1  0.495605  0.491699  0.487305  ...  2.806641 -4.513619 -2.886650 -5.039533
# 2  0.408691  0.466797  0.522461  ...  0.006713  0.006601  0.006483  0.006356
# 3  0.491699  0.489258  0.495605  ...  0.185078 -2.640925  2.107997 -0.194259
# 4  0.666992  0.648926  0.595703  ...  0.000000  0.000000  0.000000  0.000000
#
#        3559      3560      3561      3562      3563  Emotions
# ...

# %%
Emotions = pd.read_csv('./emotion1.csv')
Emotions.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.173828  0.264648  0.372559  0.486328  0.625488  0.681152  0.720703
# 1  0.250977  0.389160  0.511719  0.505859  0.510742  0.493164  0.490723
# 2  0.256348  0.354492  0.471191  0.414062  0.378418  0.373535  0.354492
# 3  0.223633  0.343750  0.476562  0.486328  0.504883  0.503418  0.489746
# 4  0.247070  0.389648  0.564941  0.642578  0.665527  0.684570  0.676270
#
#           7         8         9  ...      3555      3556      3557      3558  \
# 0  0.651855  0.562988  0.559082  ...  0.766315  0.755441  0.743671  0.731043
# 1  0.495605  0.491699  0.487305  ...  2.806641 -4.513619 -2.886650 -5.039533
# 2  0.408691  0.466797  0.522461  ...  0.006713  0.006601  0.006483  0.006356
# 3  0.491699  0.489258  0.495605  ...  0.185078 -2.640925  2.107997 -0.194259
# 4  0.666992  0.648926  0.595703  ...  0.000000  0.000000  0.000000  0.000000
#
#        3559      3560      3561      3562      3563  Emotions
# ...

# %%
print(Emotions.isna().any())
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 3560         True
# 3561         True
# 3562         True
# 3563         True
# Emotions    False
# Length: 3565, dtype: bool

# %%
Emotions=Emotions.fillna(0)
print(Emotions.isna().any())
Emotions.shape
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 3560        False
# 3561        False
# 3562        False
# 3563        False
# Emotions    False
# Length: 3565, dtype: bool
# (5760, 3565)

# %%
np.sum(Emotions.isna())
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 3560        0
# 3561        0
# 3562        0
# 3563        0
# Emotions    0
# Length: 3565, dtype: int64

# %%
#taking all rows and all cols without last col for X which include features
#taking last col for Y, which include the emotions


X = Emotions.iloc[: ,:-1].values
Y = Emotions['Emotions'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y
from sklearn.preprocessing import StandardScaler, OneHotEncoder
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
print(Y.shape)
X.shape
# Out:
# (5760, 7)
# (5760, 3564)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=42,test_size=0.2, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((4608, 3564), (4608, 7), (1152, 3564), (1152, 7))

# %%
#reshape for lstm
X_train = x_train.reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.reshape(x_test.shape[0] , x_test.shape[1] , 1)

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((4608, 3564), (4608, 7), (1152, 3564), (1152, 7))

# %%
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
model_checkpoint = ModelCheckpoint('best_model1_weights.h5', monitor='val_accuracy', save_best_only=True)

# %%
early_stop=EarlyStopping(monitor='val_accuracy',mode='auto',patience=5,restore_best_weights=True)
lr_reduction=ReduceLROnPlateau(monitor='val_accuracy',patience=3,verbose=1,factor=0.5,min_lr=0.00001)

# %%
#Reshape for CNN_LSTM MODEL

x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)
x_traincnn.shape, y_train.shape, x_testcnn.shape, y_test.shape
#x_testcnn[0]
# Out:
# ((4608, 3564, 1), (4608, 7), (1152, 3564, 1), (1152, 7))

# %%
import tensorflow.keras.layers as L

model = tf.keras.Sequential([
    L.Conv1D(512,kernel_size=5, strides=1,padding='same', activation='relu',input_shape=(x_traincnn.shape[1],1)),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    
    L.Conv1D(512,kernel_size=5,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the second max pooling layer
    
    L.Conv1D(256,kernel_size=5,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    
    L.Conv1D(256,kernel_size=3,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the fourth max pooling layer
    
    L.Conv1D(128,kernel_size=3,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=3,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the fifth max pooling layer
    
    L.Flatten(),
    L.Dense(512,activation='relu'),
    L.BatchNormalization(),
    L.Dense(7,activation='softmax')
])
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_10 (Conv1D)          (None, 3564, 512)         3072
#
#  batch_normalization_12 (Ba  (None, 3564, 512)         2048
#  tchNormalization)
#
#  max_pooling1d_10 (MaxPooli  (None, 1782, 512)         0
#  ng1D)
#
#  conv1d_11 (Conv1D)          (None, 1782, 512)         1311232
#
#  batch_normalization_13 (Ba  (None, 1782, 512)         2048
#  tchNormalization)
#
#  max_pooling1d_11 (MaxPooli  (None, 891, 512)          0
#  ng1D)
#
#  dropout_6 (Dropout)         (None, 891, 512)          0
#
#  conv1d_12 (Conv1D)          (None, 891, 256)          655616
#
#  batch_normalization_14 (Ba  (None, 891, 256)          1024
#  tchNormalization)
#
#  max_pooling1d_12 (MaxPooli  (None, 446, 256)          0
#  ng1D)
#
#  conv1d_13 (Conv1D)          (None, 446, 256)          196864
#
# ...

# %%
history=model.fit(x_traincnn, y_train, epochs=50, validation_data=(x_testcnn, y_test), batch_size=64,callbacks=[early_stop,lr_reduction,model_checkpoint])
# Out:
# Epoch 1/50
# 72/72 [==============================] - 930s 13s/step - loss: 1.6282 - accuracy: 0.4701 - val_loss: 2.8124 - val_accuracy: 0.1788 - lr: 0.0010
# Epoch 2/50
# 72/72 [==============================] - 746s 10s/step - loss: 0.8365 - accuracy: 0.6964 - val_loss: 8.7949 - val_accuracy: 0.1424 - lr: 0.0010
# Epoch 3/50
# 72/72 [==============================] - 747s 10s/step - loss: 0.5415 - accuracy: 0.8116 - val_loss: 10.9988 - val_accuracy: 0.1415 - lr: 0.0010
# Epoch 4/50
# 72/72 [==============================] - ETA: 0s - loss: 0.3397 - accuracy: 0.8902
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 72/72 [==============================] - 732s 10s/step - loss: 0.3397 - accuracy: 0.8902 - val_loss: 13.2779 - val_accuracy: 0.1424 - lr: 0.0010
# Epoch 5/50
# 72/72 [==============================] - 735s 10s/step - loss: 0.1353 - accuracy: 0.9646 - val_loss: 14.3959 - val_accuracy: 0.1424 - lr: 5.0000e-04
# Epoch 6/50
# ...

# %%
print("Accuracy of our model on test data : ", model.evaluate(x_testcnn, y_test)[1] * 100, "%")

epochs = range(1, len(history.history['accuracy']) + 1)
fig, ax = plt.subplots(1, 2, figsize=(20, 6))

train_loss = history.history['loss']
test_loss = history.history['val_loss']
train_acc = history.history['accuracy']
test_acc = history.history['val_accuracy']

ax[0].plot(epochs, train_loss, 'r', label='Training Loss')
ax[0].plot(epochs, test_loss, 'b', label='Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(epochs, train_acc, 'r', label='Training Accuracy')
ax[1].plot(epochs, test_acc, 'b', label='Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
ax[1].legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print("Accuracy of our model on test data : ", model.evaluate(x_testcnn, y_test)[1] * 100, "%")
#       3 epochs = range(1, len(history.history['accuracy']) + 1)
#       4 fig, ax = plt.subplots(1, 2, figsize=(20, 6))
#
# NameError: name 'model' is not defined

# %%
# predicting on test data.
pred_test0 = model.predict(x_testcnn)
y_pred0 = encoder.inverse_transform(pred_test0)
y_test0 = encoder.inverse_transform(y_test)

# Check for random predictions
df0 = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df0['Predicted Labels'] = y_pred0.flatten()
df0['Actual Labels'] = y_test0.flatten()

df0.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # predicting on test data.
# ----> 2 pred_test0 = model.predict(x_testcnn)
#       3 y_pred0 = encoder.inverse_transform(pred_test0)
#       4 y_test0 = encoder.inverse_transform(y_test)
#
# NameError: name 'model' is not defined

# %%
df0
# Out:
#      Predicted Labels Actual Labels
# 0               happy         happy
# 1             neutral       neutral
# 2             neutral       neutral
# 3             neutral       neutral
# 4             neutral       neutral
# ...               ...           ...
# 1147          disgust       disgust
# 1148          disgust       disgust
# 1149              sad           sad
# 1150         surprise      surprise
# 1151         surprise      surprise
#
# [1152 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test0, y_pred0)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
#cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='.1f')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()
print(classification_report(y_test0, y_pred0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.metrics import confusion_matrix,classification_report
# ----> 2 cm = confusion_matrix(y_test0, y_pred0)
#       3 plt.figure(figsize = (12, 10))
#       4 cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
#
# NameError: name 'y_test0' is not defined

# %%
# MLP for Pima Indians Dataset Serialize to JSON and HDF5
from tensorflow.keras.models import Sequential, model_from_json
model_json = model.to_json()
with open("CNN_model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("CNN_model_weights.h5")
print("Saved model to disk")
# Out:
# WARNING:tensorflow:From C:\Users\Prade\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # MLP for Pima Indians Dataset Serialize to JSON and HDF5
#       2 from tensorflow.keras.models import Sequential, model_from_json
# ----> 3 model_json = model.to_json()
#       4 with open("CNN_model.json", "w") as json_file:
#       5     json_file.write(model_json)
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.models import Sequential, model_from_json
json_file = open('CNN_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("best_model1_weights.h5")
print("Loaded model from disk")
# Out:
# WARNING:tensorflow:From C:\Users\Prade\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Prade\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Prade\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Loaded model from disk

# %%
import librosa

# %%
def zcr(data,frame_length,hop_length):
    zcr=librosa.feature.zero_crossing_rate(data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(zcr)
def rmse(data,frame_length=2048,hop_length=512):
    rmse=librosa.feature.rms(data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(rmse)
def mfcc(data,sr,frame_length=2048,hop_length=512,flatten:bool=True):
    mfcc=librosa.feature.mfcc(data,sr=sr)
    return np.squeeze(mfcc.T)if not flatten else np.ravel(mfcc.T)

def extract_features(data,sr=22050,frame_length=2048,hop_length=512):
    result=np.array([])
    
    result=np.hstack((result,
                      zcr(data,frame_length,hop_length),
                      rmse(data,frame_length,hop_length),
                      mfcc(data,sr,frame_length,hop_length)
                     ))
    return result
def get_predict_feat(path):
    d, s_rate= librosa.load(path, duration=2.5, offset=0.6)
    res=extract_features(d)
    result=np.array(res)
    result=np.reshape(result,newshape=(1,2376))
    i_result = scaler2.transform(result)
    final_result=np.expand_dims(i_result, axis=2)
    
    return final_result

# %%
import numpy as np
import librosa
def zcr(data, frame_length, hop_length):
    zcr = librosa.feature.zero_crossing_rate(data, frame_length=frame_length, hop_length=hop_length)
    return np.squeeze(zcr)

def chroma(data, sr, frame_length=2048, hop_length=512, flatten=True):
    chroma_result = librosa.feature.chroma_stft(y=data, sr=sr, n_fft=frame_length, hop_length=hop_length)
    return np.squeeze(chroma_result.T) if not flatten else np.ravel(chroma_result.T)

def mfcc(data, sr, frame_length=2048, hop_length=512, flatten=True):
    mfcc_result = librosa.feature.mfcc(y=data, sr=sr, n_fft=frame_length, hop_length=hop_length)
    return np.squeeze(mfcc_result.T) if not flatten else np.ravel(mfcc_result.T)


# Preprocessing functions
def noise(data):
    noise_amp = 0.035 * np.random.uniform() * np.amax(data)
    data = data + noise_amp * np.random.normal(size=data.shape[0])
    return data

def stretch(data):
    return librosa.effects.time_stretch(data, rate=0.8)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high=5) * 1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(y=data, sr=sampling_rate, n_steps=pitch_factor)

# Define a function to extract features from preprocessed audio data
def extract_features_adjusted(data, sr=22050, frame_length=2048, hop_length=512, target_size=3564):
    result = np.array([])
    
    # Apply preprocessing techniques
    data = noise(data)
    data = stretch(data)
    data = shift(data)
    data = pitch(data, sr)
    
    # Feature extraction
    mfcc_result = mfcc(data, sr, frame_length, hop_length)
    num_mfcc_coeffs = mfcc_result.shape[0]

    padding_size = target_size - (num_mfcc_coeffs % target_size)

    if padding_size > 0:
        mfcc_result = np.pad(mfcc_result, (0, padding_size), mode='constant')

    result = np.hstack((result,
                        zcr(data, frame_length, hop_length),
                        chroma(data, sr, frame_length, hop_length),
                        mfcc_result
                       ))

    reshaped_size = ((num_mfcc_coeffs + padding_size) // target_size) * target_size
    result = result[:reshaped_size]  
    result = result.reshape(-1, target_size, 1)
    
    return result

# %%
import librosa

# Assuming 'audio_file_path' is the path to your audio file
audio_file_path = "R_dataset/Actor_01/03-01-04-02-01-02-01.wav"

# Load audio data using librosa
audio_data, sample_rate = librosa.load(audio_file_path)

# Now 'audio_data' contains the loaded audio data and 'sample_rate' is the sampling rate of the audio

# %%
# Assuming 'audio_data' is your loaded audio data
features = extract_features_adjusted(audio_data)

# Make predictions using the loaded model
# Make predictions using the loaded model
predictions = loaded_model.predict(features)

# Print out the predictions array
print("Predictions array shape:", predictions.shape)
print("Predictions array contents:", predictions)

# Map predicted probabilities to emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
predicted_emotion_index = np.argmax(predictions)

# Iterate over each prediction
for prediction in predictions:
    # Get the index of the highest probability
    predicted_emotion_index = np.argmax(prediction)

    # Ensure the predicted emotion index is within the range of emotion labels
    if predicted_emotion_index < len(emotion_labels):
        predicted_emotion_label = emotion_labels[predicted_emotion_index]
        print("Predicted emotion:", predicted_emotion_label)
    else:
        print("Error: Predicted emotion index is out of range.")
# Out:
# 1/1 [==============================] - 0s 49ms/step
# Predictions array shape: (1, 7)
# Predictions array contents: [[0. 0. 0. 1. 0. 0. 0.]]
# Predicted emotion: happy

# %%
import numpy as np
import librosa
from tensorflow.keras.models import Sequential, model_from_json

# Preprocessing functions


# Define a function to extract features from preprocessed audio data
def extract_features_adjusted(data, sr=22050, frame_length=2048, hop_length=512, target_size=3564):
    result = np.array([])
    

    
    # Feature extraction
    mfcc_result = mfcc(data, sr, frame_length, hop_length)
    num_mfcc_coeffs = mfcc_result.shape[0]

    padding_size = target_size - (num_mfcc_coeffs % target_size)
    
    if padding_size > 0:
        mfcc_result = np.pad(mfcc_result, (0, padding_size), mode='constant')

    result = np.hstack((result,
                        zcr(data, frame_length, hop_length),
                        chroma(data, sr, frame_length, hop_length),
                        mfcc_result
                       ))

    reshaped_size = ((num_mfcc_coeffs + padding_size) // target_size) * target_size
    result = result[:reshaped_size]  
    result = result.reshape(-1, target_size, 1)
    
    return result

# Load the trained model architecture from JSON
json_file = open('CNN_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

# Load the model weights
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights("best_model1_weights.h5")
print("Loaded model from disk")

# Assuming 'audio_file_path' is the path to your audio file
audio_file_path = "R_dataset/Actor_01/03-01-04-02-01-02-01.wav"

# Load audio data using librosa
audio_data, sample_rate = librosa.load(audio_file_path)

# Define emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Extract features from audio data
features = extract_features_adjusted(audio_data)

# Make predictions using the loaded model
predictions = loaded_model.predict(features)

# Calculate the average of predictions across all samples
average_predictions = np.mean(predictions, axis=0)

# Get the index of the highest average probability
predicted_emotion_index = np.argmax(average_predictions)

# Ensure the predicted emotion index is within the range of emotion labels
if predicted_emotion_index < len(emotion_labels):
    predicted_emotion_label = emotion_labels[predicted_emotion_index]
    print("Predicted emotion:", predicted_emotion_label)
else:
    print("Error: Predicted emotion index is out of range.")
# Out:
# Loaded model from disk
# 1/1 [==============================] - 1s 722ms/step
# Predicted emotion: happy
